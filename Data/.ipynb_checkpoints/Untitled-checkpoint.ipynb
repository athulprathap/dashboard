# %%
import pandas as pd
import random

# %%
df = pd.read_csv("ReelRo_Data.csv")

# %%
df.head()
# Out:
#          Date Category  Gender          Location  Language  Video Duration  \
# 0  03-09-2022  Jewelry    Male  Himachal Pradesh  Gujarati              22
# 1   7/19/2022   Movies  Female             Bihar  Maithili              16
# 2   6/24/2022   Health  Female            Kerala   Konkani              13
# 3  04-08-2022   Movies  Female        Tamil Nadu   Konkani              27
# 4   1/28/2022    Games  Female             Bihar     Dogri              14
#
#    Time most users are viewing Age_Group
# 0                           21     30-50
# 1                           20     30-50
# 2                           15     18-30
# 3                           27     30-50
# 4                           14     18-30

# %%
ad_id = [random.randint(100, 110) for i in range(len(df))]
df['ad_id'] = ad_id

# %%
df.head()
# Out:
#          Date Category  Gender          Location  Language  Video Duration  \
# 0  03-09-2022  Jewelry    Male  Himachal Pradesh  Gujarati              22
# 1   7/19/2022   Movies  Female             Bihar  Maithili              16
# 2   6/24/2022   Health  Female            Kerala   Konkani              13
# 3  04-08-2022   Movies  Female        Tamil Nadu   Konkani              27
# 4   1/28/2022    Games  Female             Bihar     Dogri              14
#
#    Time most users are viewing Age_Group  ad_id
# 0                           21     30-50    115
# 1                           20     30-50    268
# 2                           15     18-30    277
# 3                           27     30-50    284
# 4                           14     18-30    121

# %%
df.to_csv("ad.csv")
